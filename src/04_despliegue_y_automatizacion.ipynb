# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/horsetrust_database_index.csv")
df.set_index("horse_id", inplace=True)

print("Archivo cargado correctamente")


def get_horse_trust_score(horse_id: str):
    try:
        return float(df.loc[horse_id, "horse_trust_score"])
    except KeyError:
        return f"Horse ID '{horse_id}' no encontrado."

# Uso
horse_id_input = input("Ingrese el horse_id: ")
score = get_horse_trust_score(horse_id_input)
print("Indice de confianza del caballo es:", score)
# Out:
# Archivo cargado correctamente
# Indice de confianza del caballo es: 0.982

# %%
import pandas as pd

# 1️⃣ Cargar dataset
df = pd.read_csv("../data/horsetrust_database_index.csv")

# 2️⃣ Establecer horse_id como índice
df.set_index("horse_id", inplace=True)

print("Archivo cargado correctamente ✅")

# 3️⃣ Función para consultar información del caballo
def get_horse_info(horse_id: str):
    horse_id = horse_id.strip()
    
    if horse_id not in df.index:
        return f"Horse ID '{horse_id}' no encontrado."
    
    # Columnas que queremos mostrar
    columns_to_show = [
        "horse_name",
        "height_m",
        "weight_kg",
        "length_m",
        "max_speed_kmh",
        "h_career_races",
        "h_days_since_last_race",
        "l_asking_price_usd",
        "s_disputes",
        "s_num_listings",
        "vet_total_exams",
        "vet_major_issues"
    ]
    
    horse_data = df.loc[horse_id, columns_to_show].copy()
    
    # Trust score
    trust_score = df.loc[horse_id, "horse_trust_score"] * 100
    horse_data["horse_trust_score_%"] = round(trust_score, 2)
    
    # Interpretación
    if trust_score < 70:
        interpretation = "Se recomienda revisar más datos del caballo. Índice bajo"
    elif 70 <= trust_score < 87:
        interpretation = "Confiable"
    else:
        interpretation = "Excelente"
    
    horse_data["Interpretación"] = interpretation

    # Convertir a DataFrame para imprimir sin el 'Name'
    horse_data_df = horse_data.to_frame().reset_index()
    horse_data_df.columns = ["Atributo", "Valor"]

    # Agregar horse_id como primera fila
    horse_id_row = pd.DataFrame([["horse_id", horse_id]], columns=["Atributo", "Valor"])
    horse_data_df = pd.concat([horse_id_row, horse_data_df], ignore_index=True)
    
    return horse_data_df

# 4️⃣ Uso
horse_id_input = input("Ingrese el horse_id: ")
horse_info = get_horse_info(horse_id_input)

print("\n📊 Información del caballo:")
print(horse_info.to_string(index=False))
# Out:
# Archivo cargado correctamente ✅
#
# 📊 Información del caballo:
#               Atributo     Valor
#               horse_id      H742
#             horse_name     Table
#               height_m      1.45
#              weight_kg     373.0
#               length_m       2.2
#          max_speed_kmh      59.0
#         h_career_races        19
# h_days_since_last_race     126.0
#     l_asking_price_usd   1494741
#             s_disputes         1
#         s_num_listings         1
#        vet_total_exams         1
#       vet_major_issues         0
#    horse_trust_score_%      91.4
#         Interpretación Excelente

# %%
#Consulta y verificacion en base de datos 

df = pd.read_csv("/workspaces/S02-26-Equipo-30-Web-App-/data/horsetrust_database.csv")
print(df.tail())  # Muestra las últimas filas, donde debería estar tu nuevo caballo
# Out:
#       horse_id horse_name  birth_date  h_sex                raza  height_m  \
# 996       H996       Stop  2001-12-15      M          Akhal-Teke      1.58
# 997       H997  Different  2011-12-28      M           Percherón      1.77
# 998       H998    Soldier  2008-08-30      F          Akhal-Teke      1.58
# 999       H999      Their  2008-02-11      M  Pura Raza Española      1.52
# 1000  72f8a3ea  Celestino  2021-06-25  Macho  Pura Raza Española      1.55
#
#       weight_kg  length_m  max_speed_kmh  h_temperament  ...  \
# 996       421.0       2.3           60.0  Independiente  ...
# 997       811.0       2.8           25.0    Muy calmado  ...
# 998       448.0       2.3           60.0  Independiente  ...
# 999         NaN       2.4           49.0  Noble / Dócil  ...
# 1000      524.0       2.4           50.0  Noble / Dócil  ...
#
#                     s_created_at            s_last_active_at  vet_total_exams  \
# 996   2025-10-03 08:17:42.438805  2025-11-26 08:27:53.296736              2.0
# 997   2025-01-12 22:12:30.731023  2025-06-14 03:33:29.392487              2.0
# 998   2024-05-25 11:32:15.089804  2025-11-17 21:05:40.185926              3.0
# 999   2025-08-07 02:15:57.329253  2025-11-17 12:09:52.214952              3.0
# 1000  2026-02-16 14:17:06.562139  2026-02-16 14:17:06.562144             13.0
#
#      vet_major_issues vet_avg_confidence v_exam_date completeness  vet_score  \
# 996               1.0           0.915000         NaN     1.000000   0.500000
# 997               0.0           0.855000         NaN     1.000000   1.000000
# 998               1.0           0.840000         NaN     1.000000   0.666667
# 999               0.0           0.833333         NaN     0.909091   1.000000
# 1000              1.0                NaN  2026-02-06     1.000000   0.923077
#
#      seller_score horse_trust_score
# 996          1.00          0.800000
# 997          1.00          1.000000
# 998          0.97          0.860667
# 999          0.97          0.957636
# 1000         0.97          0.963231
#
# [5 rows x 35 columns]
