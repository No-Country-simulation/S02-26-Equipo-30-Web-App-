# %%
import pandas as pd
import numpy as np
import seaborn as sd
import os

# %%
os.getcwd()
# Out:
# '/workspaces/S02-26-Equipo-30-Web-App-/src'

# %%
df = pd.read_csv("/workspaces/S02-26-Equipo-30-Web-App-/data/horsetrust_database.csv")

# %%
df.head()
# Out:
#   horse_id horse_name  birth_date h_sex                raza  height_m  \
# 0       H0        Yet  2005-09-01     F     Cuarto de Milla      1.45
# 1       H1       Look  2015-04-15     F           Appaloosa      1.41
# 2       H2      South  2007-01-28     F  Pura Sangre Inglés      1.62
# 3       H3     Season  2007-04-19     F  Pura Sangre Inglés      1.63
# 4       H4      Every  2023-05-29     F  Pura Raza Española      1.51
#
#    weight_kg  length_m  max_speed_kmh         h_temperament  ... s_last_name  \
# 0      517.0       2.3           70.0  Tranquilo / Sociable  ...       Davis
# 1      461.0       2.3           56.0   Activo / Resistente  ...       Clark
# 2      487.0       2.4           71.0   Nervioso / Atlético  ...       Clark
# 3        NaN       2.4           71.0   Nervioso / Atlético  ...      Harper
# 4      522.0       2.4           49.0         Noble / Dócil  ...         Cox
#
#    s_verified  s_disputes s_num_listings s_flagged_fraud  \
# 0        True           0             19           False
# 1        True           0             21           False
# 2        True           0             21           False
# 3        True           1             14           False
# 4        True           0              4           False
#
#                  s_created_at            s_last_active_at  vet_total_exams  \
# 0  2025-12-13 23:21:08.744869  2025-12-26 18:39:26.161093                1
# 1  2025-10-10 11:45:08.629748  2025-12-18 17:31:36.749426                3
# 2  2025-10-10 11:45:08.629748  2025-12-18 17:31:36.749426                3
# 3  2024-12-17 14:01:24.367575  2025-04-21 20:41:50.016203                1
# 4  2024-06-23 15:02:38.435730  2025-02-27 01:21:41.595814                2
#
#   vet_major_issues vet_avg_confidence
# 0                1           0.740000
# 1                1           0.903333
# 2                1           0.776667
# 3                1           0.870000
# 4                1           0.835000
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   horse_id                1000 non-null   str
#  1   horse_name              1000 non-null   str
#  2   birth_date              1000 non-null   str
#  3   h_sex                   1000 non-null   str
#  4   raza                    1000 non-null   str
#  5   height_m                938 non-null    float64
#  6   weight_kg               920 non-null    float64
#  7   length_m                1000 non-null   float64
#  8   max_speed_kmh           922 non-null    float64
#  9   h_temperament           1000 non-null   str
#  10  h_category              1000 non-null   str
#  11  h_career_races          1000 non-null   int64
#  12  h_days_since_last_race  908 non-null    float64
#  13  h_linaje                1000 non-null   str
#  14  listing_id              1000 non-null   str
#  15  seller_id               1000 non-null   str
#  16  l_listing_status        1000 non-null   str
#  17  l_asking_price_usd      1000 non-null   int64
#  18  l_created_at            1000 non-null   str
#  19  s_first_name            1000 non-null   str
#  20  s_last_name             1000 non-null   str
#  21  s_verified              1000 non-null   bool
#  22  s_disputes              1000 non-null   int64
#  23  s_num_listings          1000 non-null   int64
#  24  s_flagged_fraud         1000 non-null   bool
#  25  s_created_at            1000 non-null   str
#  26  s_last_active_at        1000 non-null   str
#  27  vet_total_exams         1000 non-null   int64
#  28  vet_major_issues        1000 non-null   int64
#  29  vet_avg_confidence      1000 non-null   float64
# dtypes: bool(2), float64(6), int64(6), str(16)
# memory usage: 220.8 KB

# %%
df.describe()
# Out:
#          height_m    weight_kg     length_m  max_speed_kmh  h_career_races  \
# count  938.000000   920.000000  1000.000000     922.000000     1000.000000
# mean     1.504979   529.569565     2.325400      50.336226       14.845000
# std      0.221275   181.693543     0.324962      15.827304        4.047142
# min      0.710000   150.000000     1.500000      20.000000        4.000000
# 25%      1.470000   447.750000     2.300000      42.000000       12.000000
# 50%      1.560000   513.000000     2.300000      55.000000       15.000000
# 75%      1.640000   623.250000     2.500000      60.000000       17.000000
# max      1.800000  1000.000000     2.800000      71.000000       29.000000
#
#        h_days_since_last_race  l_asking_price_usd   s_disputes  \
# count              908.000000        1.000000e+03  1000.000000
# mean               202.897577        1.499800e+06     0.413000
# std                112.905887        3.979668e+04     0.697795
# min                  7.000000        1.380354e+06     0.000000
# 25%                104.000000        1.472402e+06     0.000000
# 50%                203.000000        1.499758e+06     0.000000
# 75%                299.000000        1.526853e+06     1.000000
# max                400.000000        1.657049e+06     4.000000
#
#        s_num_listings  vet_total_exams  vet_major_issues  vet_avg_confidence
# count     1000.000000        1000.0000       1000.000000         1000.000000
# mean        13.618000           2.0140          0.299000            0.850900
# std          7.286094           0.8237          0.523329            0.066130
# min          1.000000           1.0000          0.000000            0.700000
# 25%          7.000000           1.0000          0.000000            0.804583
# 50%         15.000000           2.0000          0.000000            0.850000
# 75%         20.000000           3.0000          1.000000            0.895417
# max         25.000000           3.0000          3.000000            1.000000

# %% [markdown]
# # Generacion de componentes del indice de confianza Trust Horse

# %%
# Completeness score (solo columnas de caballo relevantes) para saber la falta de información

horse_cols = ["h_sex","raza","height_m","weight_kg","length_m","max_speed_kmh",
              "h_temperament","h_category","h_career_races",
              "h_days_since_last_race","h_linaje"]
df["completeness"] = 1 - df[horse_cols].isna().sum(axis=1) / len(horse_cols)

print (df["completeness"])
# Out:
# 0      1.000000
# 1      1.000000
# 2      1.000000
# 3      0.909091
# 4      1.000000
#          ...
# 995    1.000000
# 996    1.000000
# 997    1.000000
# 998    1.000000
# 999    0.909091
# Name: completeness, Length: 1000, dtype: float64

# %%
# Vet Score

df["vet_score"] = np.where(
    df["vet_total_exams"] > 0,
    1 - (df["vet_major_issues"] / df["vet_total_exams"]),
    0.5
)

# %%
# Seller score
df["seller_score"] = (
    0.4 * df["s_verified"].astype(int) + 
    0.3 * (1 - np.minimum(df["s_disputes"]/10,1)) +
    0.3 * (1 - df["s_flagged_fraud"].astype(int))
)

# %%
# Horse trust score (ponderación final)
df["horse_trust_score"] = 0.4 * df["completeness"] + 0.4 * df["vet_score"] + 0.2 * df["seller_score"]

# Revisar resultados
df[["horse_id","horse_trust_score","completeness","vet_score","seller_score"]].head()
# Out:
#   horse_id  horse_trust_score  completeness  vet_score  seller_score
# 0       H0           0.600000      1.000000   0.000000          1.00
# 1       H1           0.866667      1.000000   0.666667          1.00
# 2       H2           0.866667      1.000000   0.666667          1.00
# 3       H3           0.557636      0.909091   0.000000          0.97
# 4       H4           0.800000      1.000000   0.500000          1.00

# %% [markdown]
# Se ha generado el Horse Trust Score con la pondercion de 3 componentes de informacion del caballo , registro veterinario y

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   horse_id                1000 non-null   str
#  1   horse_name              1000 non-null   str
#  2   birth_date              1000 non-null   str
#  3   h_sex                   1000 non-null   str
#  4   raza                    1000 non-null   str
#  5   height_m                938 non-null    float64
#  6   weight_kg               920 non-null    float64
#  7   length_m                1000 non-null   float64
#  8   max_speed_kmh           922 non-null    float64
#  9   h_temperament           1000 non-null   str
#  10  h_category              1000 non-null   str
#  11  h_career_races          1000 non-null   int64
#  12  h_days_since_last_race  908 non-null    float64
#  13  h_linaje                1000 non-null   str
#  14  listing_id              1000 non-null   str
#  15  seller_id               1000 non-null   str
#  16  l_listing_status        1000 non-null   str
#  17  l_asking_price_usd      1000 non-null   int64
#  18  l_created_at            1000 non-null   str
#  19  s_first_name            1000 non-null   str
#  20  s_last_name             1000 non-null   str
#  21  s_verified              1000 non-null   bool
#  22  s_disputes              1000 non-null   int64
#  23  s_num_listings          1000 non-null   int64
#  24  s_flagged_fraud         1000 non-null   bool
#  25  s_created_at            1000 non-null   str
#  26  s_last_active_at        1000 non-null   str
#  27  vet_total_exams         1000 non-null   int64
#  28  vet_major_issues        1000 non-null   int64
#  29  vet_avg_confidence      1000 non-null   float64
#  30  completeness            1000 non-null   float64
#  31  vet_score               1000 non-null   float64
#  32  seller_score            1000 non-null   float64
#  33  horse_trust_score       1000 non-null   float64
# dtypes: bool(2), float64(10), int64(6), str(16)
# memory usage: 252.1 KB

# %%
# Nuevo Dataset con el Trust Index

import os
os.getcwd()
os.makedirs("../data", exist_ok=True)
df.to_csv("../data/horsetrust_database_index.csv", index=True)
