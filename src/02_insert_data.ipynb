# %%
from pymongo import MongoClient
from faker import Faker
import pandas as pd
import numpy as np
import random
import uuid # para uuid4() genera identificadores aleatorios de 128 bits, estándar para sistemas productivos y protección de identidad.

fake = Faker()

# %% [markdown]
# Conexion con Mongo

# %%
# URI de tu cluster real
uri = "mongodb+srv://gabyjargudo82_db_user:BTplZ4YXmOp70kje@horse-trust.4pc35q1.mongodb.net/?appName=horse-trust"

# Conexión al cluster
client = MongoClient(uri)

# Crear/usar base de datos
db = client["horse_trust_db"]

# %% [markdown]
# Verificacion Rapida

# %%
print(db.list_collection_names())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(db.list_collection_names())
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/database.py:1241, in Database.list_collection_names(self, session, filter, comment, **kwargs)
#    1209 def list_collection_names(
#    1210     self,
#    1211     session: Optional[ClientSession] = None,
#    (...)   1214     **kwargs: Any,
#    1215 ) -> list[str]:
#    1216     """Get a list of all the collection names in this database.
#    1217
#    1218     For example, to list all non-system collections::
#    (...)   1239     .. versionadded:: 3.6
#    1240     """
# -> 1241     return self._list_collection_names(session, filter, comment, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/database.py:1206, in Database._list_collection_names(self, session, filter, comment, **kwargs)
#    1202     if not filter or (len(filter) == 1 and "name" in filter):
#    1203         kwargs["nameOnly"] = True
#    1205 return [
# -> 1206     result["name"] for result in self._list_collections_helper(session=session, **kwargs)
#    1207 ]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/database.py:1144, in Database._list_collections_helper(self, session, filter, comment, **kwargs)
#    1136 def _cmd(
#    1137     session: Optional[ClientSession],
#    1138     _server: Server,
#    1139     conn: Connection,
#    1140     read_preference: _ServerMode,
#    1141 ) -> CommandCursor[MutableMapping[str, Any]]:
#    1142     return self._list_collections(conn, session, read_preference=read_preference, **kwargs)
# -> 1144 return self._client._retryable_read(
#    1145     _cmd, read_pref, session, operation=_Op.LIST_COLLECTIONS
#    1146 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2048, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
#    2047 with self._tmp_session(session) as s:
# -> 2048     return self._retry_internal(
#    2049         func,
#    2050         s,
#    2051         None,
#    2052         operation,
#    2053         is_read=True,
#    2054         address=address,
#    2055         read_pref=read_pref,
#    2056         retryable=retryable,
#    2057         operation_id=operation_id,
#    2058     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2908, in _ClientConnectionRetryable._read(self)
#    2903 def _read(self) -> T:
#    2904     """Wrapper method for read-type retryable client executions
#    2905
#    2906     :return: Output for func()'s call
#    2907     """
# -> 2908     self._server = self._get_server()
#    2909     assert self._read_pref is not None, "Read Preference required on read calls"
#    2910     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2911         conn,
#    2912         read_pref,
#    2913     ):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)    425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)    400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pymongo/synchronous/topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)    357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)    372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-cm7yj7o-shard-00-01.4pc35q1.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-cm7yj7o-shard-00-00.4pc35q1.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-cm7yj7o-shard-00-02.4pc35q1.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 698c892dafa24507596bb620, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-cm7yj7o-shard-00-00.4pc35q1.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-cm7yj7o-shard-00-00.4pc35q1.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-cm7yj7o-shard-00-01.4pc35q1.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-cm7yj7o-shard-00-01.4pc35q1.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-cm7yj7o-shard-00-02.4pc35q1.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-cm7yj7o-shard-00-02.4pc35q1.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %% [markdown]
# ## Generacion de Data Random

# %%
# ==============================
# Setup
# ==============================

fake = Faker()
random.seed(42)
np.random.seed(42)

NUM_HORSES = 1000
NUM_SELLERS = 200

# ==============================
# Diccionario completo de razas
# ==============================

BREEDS = {
    "Pura Sangre Inglés": {"height_m": (1.6,1.7), "weight_kg": (450,500), "length_m":2.4, "max_speed_kmh":71, "temperament":"Nervioso / Atlético", "main_use":"Carreras y Salto"},
    "Cuarto de Milla": {"height_m": (1.4,1.6), "weight_kg": (500,600), "length_m":2.3, "max_speed_kmh":70, "temperament":"Tranquilo / Sociable", "main_use":"Rodeo y Trabajo"},
    "Árabe": {"height_m": (1.4,1.5), "weight_kg": (350,450), "length_m":2.2, "max_speed_kmh":(55,60), "temperament":"Inteligente / Leal", "main_use":"Endurance (Raid)"},
    "Hannoveriano": {"height_m": (1.6,1.7), "weight_kg": (600,650), "length_m":2.5, "max_speed_kmh":50, "temperament":"Equilibrado", "main_use":"Salto y Doma"},
    "Akhal-Teke": {"height_m": (1.5,1.6), "weight_kg": (420,480), "length_m":2.3, "max_speed_kmh":60, "temperament":"Independiente", "main_use":"Resistencia"},
    "Pura Raza Española": {"height_m": (1.5,1.6), "weight_kg": (500,550), "length_m":2.4, "max_speed_kmh":(45,50), "temperament":"Noble / Dócil", "main_use":"Doma y Exhibición"},
    "Frisón": {"height_m": (1.6,1.7), "weight_kg": (600,800), "length_m":2.6, "max_speed_kmh":(40,45), "temperament":"Manso / Dispuesto", "main_use":"Tiro y Cine"},
    "Percherón": {"height_m": (1.6,1.8), "weight_kg": (800,1000), "length_m":2.8, "max_speed_kmh":(25,30), "temperament":"Muy calmado", "main_use":"Tiro pesado"},
    "Appaloosa": {"height_m": (1.4,1.6), "weight_kg": (450,550), "length_m":2.3, "max_speed_kmh":(55,60), "temperament":"Activo / Resistente", "main_use":"Rutas y Western"},
    "Shetland (Poni)": {"height_m": (0.7,1.1), "weight_kg": (150,200), "length_m":1.5, "max_speed_kmh":20, "temperament":"Testarudo / Fuerte", "main_use":"Niños y Compañía"}
}

# ==============================
# Generador Horse
# ==============================

def generate_horse() -> dict:
    breed = random.choice(list(BREEDS.keys()))
    b = BREEDS[breed]

    is_complete = random.random() < 0.6
    maybe_missing = ["height_m","weight_kg","max_speed_kmh","h_career_top3_rate","h_days_since_last_race"]
    missing_field = random.choice(maybe_missing) if not is_complete else None

    def val_or_none(field, val):
        return None if field == missing_field else val

    return {
        "horse_id": f"H-{uuid.uuid4().hex[:8]}",
        "birth_date": fake.date_of_birth(minimum_age=2, maximum_age=30),
        "h_sex": random.choice(["M","F"]),
        "raza": breed,
        "height_m": val_or_none("height_m", round(random.uniform(*b["height_m"]),2)),
        "weight_kg": val_or_none("weight_kg", random.randint(*b["weight_kg"])),
        "length_m": b["length_m"],
        "max_speed_kmh": val_or_none("max_speed_kmh",
            random.randint(*b["max_speed_kmh"]) if isinstance(b["max_speed_kmh"], tuple) else b["max_speed_kmh"]),
        "h_temperament": b["temperament"],
        "h_category": b["main_use"],
        "h_career_races": np.random.poisson(15),
        "h_career_top3_rate": val_or_none("h_career_top3_rate", round(random.uniform(0.1,0.7),2)),
        "h_days_since_last_race": val_or_none("h_days_since_last_race", random.randint(7,400)),
        "h_linaje": random.choices(["Sí","No","Desconocido"],weights=[0.4,0.4,0.2])[0]
    }

# ==============================
# Generador Seller
# ==============================

def generate_seller(i: int) -> dict:
    created_at = fake.date_time_between(start_date="-4y", end_date="-6m")
    return {
        "seller_id": f"S-{uuid.uuid4().hex[:6]}",
        "s_first_name": fake.first_name(),
        "s_last_name": fake.last_name(),
        "s_verified": random.random() > 0.2,
        "s_disputes": int(np.random.poisson(0.4)),
        "s_success_rate": round(random.uniform(0.6,0.95),2),
        "s_num_listings": random.randint(1,25),
        "s_flagged_fraud": random.random() < 0.05,
        "s_created_at": created_at,
        "s_last_active_at": fake.date_time_between(start_date=created_at)
    }

# ==============================
# Generador Listing
# ==============================

def generate_listing(horse_id, seller_id) -> dict:
    return {
        "listing_id": f"L-{uuid.uuid4().hex[:6]}",
        "horse_id": horse_id,
        "seller_id": seller_id,
        "l_listing_status": random.choices(["active","sold","withdrawn"],weights=[0.6,0.25,0.15])[0],
        "l_asking_price_usd": int(np.random.normal(1500000,40000)),
        "l_price_vs_market_ratio": round(random.uniform(0.6,1.8),2),
        "l_anomaly_score": round(random.uniform(0,1),2),
        "l_verified_listing": random.random() > 0.15,
        "l_created_at": fake.date_time_between(start_date="-1y")
    }

# ==============================
# Generador Vet
# ==============================

def generate_vet_record(horse_id) -> dict:
    return {
        "horse_id": horse_id,
        "v_exam_date": fake.date_time_between(start_date="-2y"),
        "v_major_issue": random.random() < 0.15,
        "v_confidence_score": round(random.uniform(0.7,1.0),2)
    }

# ==============================
# GENERACIÓN PRINCIPAL
# ==============================

# 1️⃣ Horses
horses = [generate_horse() for _ in range(NUM_HORSES)]
horses_df = pd.DataFrame(horses)

# 2️⃣ Sellers
sellers = [generate_seller(i) for i in range(NUM_SELLERS)]
sellers_df = pd.DataFrame(sellers)

# 3️⃣ Asignación Horse → Seller (máx 8)
seller_horses = {s["seller_id"]: [] for s in sellers}

for horse in horses:
    assigned = False
    while not assigned:
        seller = random.choice(sellers)
        if len(seller_horses[seller["seller_id"]]) < 8:
            seller_horses[seller["seller_id"]].append(horse["horse_id"])
            assigned = True

# 4️⃣ Listings
listings = []
for seller_id, horse_list in seller_horses.items():
    for h_id in horse_list:
        listings.append(generate_listing(h_id, seller_id))

listings_df = pd.DataFrame(listings)

# 5️⃣ Vet records
vet_records = []
for h in horses:
    for _ in range(random.randint(1,3)):
        vet_records.append(generate_vet_record(h["horse_id"]))

vet_records_df = pd.DataFrame(vet_records)

# ==============================
# AGREGACIÓN VET
# ==============================

vet_agg_df = (
    vet_records_df
    .groupby("horse_id")
    .agg(
        vet_total_exams=("v_exam_date", "count"),
        vet_major_issues=("v_major_issue", "sum"),
        vet_avg_confidence=("v_confidence_score", "mean")
    )
    .reset_index()
)

# ==============================
# MERGE FINAL
# ==============================

final_df = (
    horses_df
    .merge(listings_df, on="horse_id", how="inner")
    .merge(sellers_df, on="seller_id", how="left")
    .merge(vet_agg_df, on="horse_id", how="left")
)

# ==============================
# VALIDACIÓN
# ==============================

print("Horses:", horses_df.shape)
print("Listings:", listings_df.shape)
print("Final dataset:", final_df.shape)

# ==============================
# EXPORT CSV ÚNICO
# ==============================

final_df.to_csv("horsetrust_database.csv", index=False)

print("✅ CSV generado correctamente")
# Out:
# Horses: (1000, 14)
# Listings: (1000, 9)
# Final dataset: (1000, 34)
# ✅ CSV generado correctamente
